# %%
import json

# %% [markdown]
# HAPTIC --> slap
# GENDER (sonic x->1) --> eyes
# SONIC --> voice (whistle/hum/HAH)
# SPECTRAL --> hands

# %%
with open('spem-sentence-encoding.json') as f:
    encoding = json.load(f)

# %%
encoding['2'].keys()
# Out:
# dict_keys(['hand', 'voice', 'slap', 'eyes'])

# %%
len(encoding['2']['hand'])
# Out:
# 256

# %% [markdown]
# Hand is ~2 per word, in excel is 6 per word (2 per second).

# %%
6*21
# Out:
# 126

# %% [markdown]
# Should have 126, 6 per word.

# %%
with open('../HE-DEMS sentence encodings (scores)/random_sentence_1.json') as f:
    rand_1 = json.load(f)

# %%
rand_1[0]
# Out:
# {'m1': {'phoneme': {'emission': {'outer': 7,
#     'inner': 3,
#     'emfreq': 1005.0,
#     'width': 'doubly-ext'},
#    'sounds': [{'outer': 5,
#      'inner': 3,
#      'emfreq': 1282.0,
#      'soundfreq': 862.6906570008321},
#     {'outer': 7, 'inner': 3, 'emfreq': 1005.0, 'soundfreq': 833.3442489743459},
#     {'outer': 5,
#      'inner': 2,
#      'emfreq': 434.047,
#      'soundfreq': 732.1300834924069}],
#    'haptics': {'outer': 6, 'inner': 4}},
#   'emshape': 'none',
#   'soundshape': ['up', 'free', 'free']},
#  'm2': {'phoneme': {'emission': {'outer': 5,
#     'inner': 1,
#     'emfreq': 94.974,
#     'width': 'IR-ext'},
#    'sounds': [{'outer': 5,
#      'inner': 2,
#      'emfreq': 434.047,
#      'soundfreq': 732.1300834924069},
#     {'outer': 6, 'inner': 3, 'emfreq': 1094.0, 'soundfreq': 843.5734585375394},
#     {'outer': 7,
#      'inner': 5,
#      'emfreq': 4654.0,
#      'soundfreq': 1018.118903571457}],
#    'haptics': {'outer': 6, 'inner': 3}},
# ...
