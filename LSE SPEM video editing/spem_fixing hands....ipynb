# %%
#load file from json
import json
with open("sentence-encoding.json", "r") as file:
    sentence_encoding = json.load(file)

# %%
for i in sentence_encoding["7"]["voice"]:
    print(i)
# Out:
# ['(7, 3)', 2.0]
# ['(7, 4)', 2.0]
# ['5', 2.0]
# ['5', 3.0]
# ['6', 3.0]
# ['6', 2.0]
# ['5', 2.0]
# ['(7, 5)', 2.0]
# ['HAH', 6.0]
# ['5', 2.0]
# ['6', 2.0]
# ['(7, 3)', 2.0]
# ['(7, 3)', 6.0]
# ['6', 3.0]
# ['HAH', 3.0]
# ['6', 2.0]
# ['(7, 5)', 2.0]
# ['6', 2.0]
# ['6', 3.0]
# ['5', 3.0]
# ['6', 3.0]
# ['4', 3.0]
# ['4', 2.0]
# ['(7, 3)', 2.0]
# ['(7, 5)', 2.0]
# ['6', 3.0]
# ['(7, 3)', 3.0]
# ['(7, 4)', 2.0]
# ['5', 2.0]
# ['6', 2.0]
# ['(7, 5)', 2.0]
# ['HAH', 2.0]
# ['HAH', 2.0]
# ['HAH', 3.0]
# ['(7, 5)', 3.0]
# ['6', 6.0]
# ['6', 2.0]
# ['(7, 4)', 2.0]
# ['6', 2.0]
# ['5', 2.0]
# ['5', 2.0]
# ['6', 2.0]
# ['5', 6.0]
# ['5', 3.0]
# ['HAH', 3.0]
# ['6', 3.0]
# ['6', 3.0]
# ['5', 6.0]
# ['5', 3.0]
# ['6', 3.0]
# ['5', 2.0]
# ['HAH', 2.0]
# ['6', 2.0]
# ['(7, 3)', 6.0]
# ['6', 6.0]
# ['6', 3.0]
# ['6', 3.0]
# ['6', 2.0]
# ['(7, 3)', 2.0]
# ['(7, 4)', 2.0]
# ['6', 2.0]
# ['HAH', 2.0]
# ['(7, 5)', 2.0]
# ['4', 3.0]
# ['5', 3.0]
# ['5', 3.0]
# ['6', 3.0]
# ['6', 2.0]
# ['5', 2.0]
# ...

# %%
sum = 0b
i = 0
for j in range (len(sentence_encoding["4"]['hand'][63:])):
    info = sentence_encoding["5"]['hand'][j+63]
    sum += info[1]
    print(info[0], sum, j, i)
    if sum == 36.0:
        i += 1
        sum = 0
# Out:
# U<D 3.0 0 0
# U< 6.0 1 0
# U<I< 9.0 2 0
# I< 12.0 3 0
# I< 15.0 4 0
# I< 18.0 5 0
# I< 21.0 6 0
# I< 24.0 7 0
# I< 27.0 8 0
# I<N 30.0 9 0
# I< 33.0 10 0
# I< 36.0 11 0
# I<D< 3 12 1
# D< 6.0 13 1
# D<D 9.0 14 1
# D< 12.0 15 1
# D<N 15.0 16 1
# D< 18.0 17 1
# D< 21.0 18 1
# D< 24.0 19 1
# D< 27.0 20 1
# D<E 30.0 21 1
# D<I< 33.0 22 1
# I<N 36.0 23 1
# I<D< 3 24 2
# D< 6.0 25 2
# D< 9.0 26 2
# D<D 12.0 27 2
# D<U< 15.0 28 2
# U<E 17.5 29 2
# U<O< 18.5 30 2
# O<N 21.0 31 2
# O< 24.0 32 2
# O<U< 27.0 33 2
# U< 30.0 34 2
# U<E 33.0 35 2
# U< 36.0 36 2
# U<I< 3 37 3
# I< 6.0 38 3
# I< 9.0 39 3
# I< 12.0 40 3
# I< 15.0 41 3
# I<N 18.0 42 3
# I<U< 21.0 43 3
# U< 24.0 44 3
# U< 27.0 45 3
# U<E 30.0 46 3
# U< 33.0 47 3
# U< 36.0 48 3
# U<O< 3 49 4
# O<D 5.5 50 4
# O<U< 6.5 51 4
# U<D 9.0 52 4
# U< 12.0 53 4
# U< 15.0 54 4
# U<N 18.0 55 4
# U<N 21.0 56 4
# U< 24.0 57 4
# U<I< 27.0 58 4
# I< 30.0 59 4
# I< 33.0 60 4
# I<E 36.0 61 4
# I< 3.0 62 5
# I<N 6.0 63 5
# I<U< 9.0 64 5
# U<E 12.0 65 5
# ...

# %%
sentence_encoding["4"]["hand"][84] = ['I<', 3.0]
sentence_encoding["4"]["hand"] = sentence_encoding["4"]["hand"][:85] + sentence_encoding["4"]["hand"][86:]
sentence_encoding["4"]["hand"][85] = ["U<N", 3.0]

# %%
sentence_encoding["4"]["hand"][96] = ["D<U<", 3.0]
sentence_encoding["4"]["hand"] = sentence_encoding["4"]["hand"][:97] + sentence_encoding["4"]["hand"][98:]
sentence_encoding["4"]["hand"][97] = ["U<E", 3.0]

# %%
sentence_encoding["4"]["hand"][108] = ["U<O<", 3.0]
sentence_encoding["4"]["hand"] = sentence_encoding["4"]["hand"][:109] + sentence_encoding["4"]["hand"][110:]
sentence_encoding["4"]["hand"][109] = ["O<", 3.0]

# %%
del sentence_encoding["4"]["hand"][]
