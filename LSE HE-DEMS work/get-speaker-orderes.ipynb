# %%
import numpy as np

# %%
sentences = [i+1 for i in range(16)]

# %%
for j in range(8):
    choice = np.random.choice(sentences)
    print(choice)
    sentences.remove(choice)
# Out:
# 14
# 2
# 8
# 16
# 1
# 7
# 5
# 4
